# %% [markdown]
# <a href="https://colab.research.google.com/github/mcarmoy/TAREA_IDEs/blob/desarrollo/Analisis_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

puntos = []
for x in range(5):
    calculo = math.sqrt(x)
    puntos.append(calculo)
    print(f"Raíz de {x} es {calculo}")
# Out:
# Raíz de 0 es 0.0
# Raíz de 1 es 1.0
# Raíz de 2 es 1.4142135623730951
# Raíz de 3 es 1.7320508075688772
# Raíz de 4 es 2.0
